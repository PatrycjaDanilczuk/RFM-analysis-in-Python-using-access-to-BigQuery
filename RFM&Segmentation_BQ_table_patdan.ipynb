# %% [markdown]
# <a href="https://colab.research.google.com/github/PatrycjaDanilczuk/RFM-analysis-in-Python-using-access-to-BigQuery/blob/main/RFM%26Segmentation_BQ_table_patdan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RFM analysis in Python using Big Query dataset and prompt user for time range selection for analysis

# %% [markdown]
# Project Description:
#
# Create reusable Python code to provide Segmentation and RFM analysis of the "rfm" data table hosted in the Turing College BigQuery project.
#
# Apply date range selection for analysis as a user prompt for the required period for analysis. When the "rfm" table is updated or incremented with new periods, the user should be able to select dates for analysis within the current data in the dataset.
#
# For the selected date range, the code provides:
#
# - calculation of recency, frequency and monetary values,
# - visualization of recency, frequency and monetary values distribution (boxplots, histograms),
# - transformation of these values into R, F and M scores using quartiles or custom cutoffs, according to the most appropriate approach based on the data distribution,
# - application of Segments based on the calculated RFM score,
# - data visualizations, allowing the user to make own insights.

# %% [markdown]
# ## Step 1. Importing data from Big Query to Google Colab

# %% [markdown]
# ### Accessing BigQuery Dataset using Google Colab

# %%
#Accessing BigQuery
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
project_id = 'tc-da-1'

# %%
from google.cloud import bigquery

# %%
client = bigquery.Client(project=project_id)
dataset_ref = client.dataset("turing_data_analytics", project = project_id)
dataset = client.get_dataset(dataset_ref)

# %% [markdown]
# ### Getting list of tables in Dataset

# %%
#Getting list of tables from BigQuery TC project
tables = list(client.list_tables(dataset))

for table in tables:
  print(table.table_id)
# Out:
# adsense_monthly
# bank_loans_data
# bank_loans_stats
# cookie_cats
# raw_events
# rfm
# rfm_quantiles
# rfm_score
# rfm_value
# stackoverflow_posts
# subscriptions
# wa_marketing_campaign

# %%
#accessing rfm table object, which is the 4th in the list
print(tables[5])
print(tables[5].table_id)

sql_table_id = tables[5]
sql_table_id
# Out:
# <google.cloud.bigquery.table.TableListItem object at 0x7963232bad10>
# rfm

# %% [markdown]
# ### Importing data to DataFrame

# %%
#Importing rfm data to a DataFrame
rfm_raw_df = client.list_rows(sql_table_id).to_dataframe()

# %%
rfm_raw_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536414     22139                                 None        56
# 1         536544     22081           RIBBON REEL FLORA + FAUNA          1
# 2         536544     22100             SKULLS SQUARE TISSUE BOX         1
# 3         536544     22114    HOT WATER BOTTLE TEA AND SYMPATHY         3
# 4         536544     22196         SMALL HEART MEASURING SPOONS         2
# ...          ...       ...                                  ...       ...
# 541904    566405     23005     TRAVEL CARD WALLET I LOVE LONDON        48
# 541905    566405     22732       3D VINTAGE CHRISTMAS STICKERS         18
# 541906    566405     22940            FELTCRAFT CHRISTMAS FAIRY        24
# 541907    566405     23309  SET OF 60 I LOVE LONDON CAKE CASES         48
# 541908    566405     22733    3D TRADITIONAL CHRISTMAS STICKERS        18
#
#                      InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 11:52:00+00:00       0.00        <NA>  United Kingdom
# 1      2010-12-01 14:32:00+00:00       3.36        <NA>  United Kingdom
# 2      2010-12-01 14:32:00+00:00       2.51        <NA>  United Kingdom
# 3      2010-12-01 14:32:00+00:00       8.47        <NA>  United Kingdom
# 4      2010-12-01 14:32:00+00:00       1.66        <NA>  United Kingdom
# ...                          ...        ...         ...             ...
# 541904 2011-09-12 13:41:00+00:00       0.42       17919  United Kingdom
# 541905 2011-09-12 13:41:00+00:00       1.25       17919  United Kingdom
# 541906 2011-09-12 13:41:00+00:00       4.25       17919  United Kingdom
# 541907 2011-09-12 13:41:00+00:00       0.55       17919  United Kingdom
# 541908 2011-09-12 13:41:00+00:00       1.25       17919  United Kingdom
#
# [541909 rows x 8 columns]

# %% [markdown]
# ## Step 2. Exploratory data analysis

# %% [markdown]
# ### Setting up Python enviroment for exploratory data analysis

# %%
# setting up enviroment for exploratory data analysis
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
print('Setup complete')
# Out:
# Setup complete

# %% [markdown]
# ### Checking metadata, dataset quality, description, validating import results

# %% [markdown]
# #### Checkig columns and dtypes

# %%
# getting info about the data set and data types
rfm_raw_df.info() #CustomerID need to be converted to string. Other columns have correct data type eg. InvoiceDate is datetime data type.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  Int64
#  4   InvoiceDate  541909 non-null  datetime64[us, UTC]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  Int64
#  7   Country      541909 non-null  object
# dtypes: Int64(2), datetime64[us, UTC](1), float64(1), object(4)
# memory usage: 34.1+ MB

# %% [markdown]
# #### Checkig number of rows

# %%
rfm_raw_df.shape
#Validated the result with rfm table in BigQuery - there are exactly 541909 rows and 8 columns - the data set has been imported coreclly.
# Out:
# (541909, 8)

# %% [markdown]
# #### Detecting null values in the data set

# %%
# detecting null values
rfm_raw_df.isnull().sum() #Instances with null values in CustomerID column need to be removed.
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# #### Checking data set time range

# %%
# checkig time range of the data on InviceDate column
rfm_raw_df.sort_values(by='InvoiceDate', inplace=True)
rfm_raw_df.head()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 430882    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 430878    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 430879    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 430880    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 430881    536365     71053                  WHITE METAL LANTERN         6
#
#                      InvoiceDate  UnitPrice  CustomerID         Country
# 430882 2010-12-01 08:26:00+00:00       2.75       17850  United Kingdom
# 430878 2010-12-01 08:26:00+00:00       3.39       17850  United Kingdom
# 430879 2010-12-01 08:26:00+00:00       3.39       17850  United Kingdom
# 430880 2010-12-01 08:26:00+00:00       7.65       17850  United Kingdom
# 430881 2010-12-01 08:26:00+00:00       3.39       17850  United Kingdom

# %%
rfm_raw_df.tail()
# Out:
#        InvoiceNo StockCode                    Description  Quantity  \
# 342461    581587     23254  CHILDRENS CUTLERY DOLLY GIRL          4
# 342462    581587     22555      PLASTERS IN TIN STRONGMAN        12
# 342463    581587     22613    PACK OF 20 SPACEBOY NAPKINS        12
# 342457    581587     23256    CHILDRENS CUTLERY SPACEBOY          4
# 342450    581587     22728      ALARM CLOCK BAKELIKE PINK         4
#
#                      InvoiceDate  UnitPrice  CustomerID Country
# 342461 2011-12-09 12:50:00+00:00       4.15       12680  France
# 342462 2011-12-09 12:50:00+00:00       1.65       12680  France
# 342463 2011-12-09 12:50:00+00:00       0.85       12680  France
# 342457 2011-12-09 12:50:00+00:00       4.15       12680  France
# 342450 2011-12-09 12:50:00+00:00       3.75       12680  France

# %%
#checking the earliest date in the dataframe
min_date = rfm_raw_df['InvoiceDate'].min()
min_date
# Out:
# Timestamp('2010-12-01 08:26:00+0000', tz='UTC')

# %%
#accessing the row with the earliest date by index
min_date_index = rfm_raw_df['InvoiceDate'].idxmin()
rfm_raw_df.loc[min_date_index]
# Out:
# InvoiceNo                              536365
# StockCode                              84406B
# Description    CREAM CUPID HEARTS COAT HANGER
# Quantity                                    8
# InvoiceDate         2010-12-01 08:26:00+00:00
# UnitPrice                                2.75
# CustomerID                              17850
# Country                        United Kingdom
# Name: 430882, dtype: object

# %%
rfm_raw_df['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00+0000', tz='UTC')

# %%
#accessing the row with the latest date by index
max_date_index = rfm_raw_df['InvoiceDate'].idxmax()
rfm_raw_df.loc[max_date_index]
# Out:
# InvoiceNo                          581587
# StockCode                           22730
# Description    ALARM CLOCK BAKELIKE IVORY
# Quantity                                4
# InvoiceDate     2011-12-09 12:50:00+00:00
# UnitPrice                            3.75
# CustomerID                          12680
# Country                            France
# Name: 342455, dtype: object

# %% [markdown]
# Checked with rfm BigQuery table - dates have been imported corectly.

# %% [markdown]
# #### Checkig data distribution

# %%
# getting values distribution description
rfm_raw_df.describe() #Instances with negative values of Quanitity and Unit price need to be removed
# Out:
#          Quantity      UnitPrice   CustomerID
# count    541909.0  541909.000000     406829.0
# mean      9.55225       4.611114  15287.69057
# std    218.081158      96.759853  1713.600303
# min      -80995.0  -11062.060000      12346.0
# 25%           1.0       1.250000      13953.0
# 50%           3.0       2.080000      15152.0
# 75%          10.0       4.130000      16791.0
# max       80995.0   38970.000000      18287.0

# %% [markdown]
# ## Step 3. Cleaning data set for further analysis

# %%
#creating copy of the dataframe
rfm_cleaned = rfm_raw_df.copy()

# %% [markdown]
# ### Removing null values

# %%
#remving null instances for CustomerID column
rfm_cleaned = rfm_cleaned.dropna(subset=['CustomerID'])
rfm_cleaned.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
rfm_cleaned.head()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 430882    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 430878    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 430879    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 430880    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 430881    536365     71053                  WHITE METAL LANTERN         6
#
#                      InvoiceDate  UnitPrice  CustomerID         Country
# 430882 2010-12-01 08:26:00+00:00       2.75       17850  United Kingdom
# 430878 2010-12-01 08:26:00+00:00       3.39       17850  United Kingdom
# 430879 2010-12-01 08:26:00+00:00       3.39       17850  United Kingdom
# 430880 2010-12-01 08:26:00+00:00       7.65       17850  United Kingdom
# 430881 2010-12-01 08:26:00+00:00       3.39       17850  United Kingdom

# %%
rfm_cleaned.shape
# Out:
# (406829, 8)

# %% [markdown]
# ### Converting data types

# %%
# converting CustomerID from integer to a string data type
rfm_cleaned['CustomerID'] = rfm_cleaned['CustomerID'].astype(str)
rfm_cleaned.dtypes
# Out:
# InvoiceNo                   object
# StockCode                   object
# Description                 object
# Quantity                     Int64
# InvoiceDate    datetime64[us, UTC]
# UnitPrice                  float64
# CustomerID                  object
# Country                     object
# dtype: object

# %% [markdown]
# ### Removing duplicates

# %%
# Check for duplicates in the entire DataFrame
duplicates = rfm_cleaned.duplicated()

# %%
# Check if any row is a duplicate
if duplicates.any():
    print("DataFrame contains duplicates.")
else:
    print("DataFrame does not contain duplicates.")
# Out:
# DataFrame contains duplicates.

# %%
#removing duplicates
rfm_cleaned = rfm_cleaned.drop_duplicates()
rfm_cleaned.shape #removed 5225 duplicated rows
# Out:
# (401604, 8)

# %% [markdown]
# ### Transforming InvoiceDate to date type

# %%
rfm_cleaned.dtypes
# Out:
# InvoiceNo                   object
# StockCode                   object
# Description                 object
# Quantity                     Int64
# InvoiceDate    datetime64[us, UTC]
# UnitPrice                  float64
# CustomerID                  object
# Country                     object
# dtype: object

# %%
rfm_cleaned.head()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 430882    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 430878    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 430879    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 430880    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 430881    536365     71053                  WHITE METAL LANTERN         6
#
#                      InvoiceDate  UnitPrice CustomerID         Country
# 430882 2010-12-01 08:26:00+00:00       2.75      17850  United Kingdom
# 430878 2010-12-01 08:26:00+00:00       3.39      17850  United Kingdom
# 430879 2010-12-01 08:26:00+00:00       3.39      17850  United Kingdom
# 430880 2010-12-01 08:26:00+00:00       7.65      17850  United Kingdom
# 430881 2010-12-01 08:26:00+00:00       3.39      17850  United Kingdom

# %%
# InvoiceDate column is a datetime type, we can convert it to date
rfm_cleaned['InvoiceDate'] = rfm_cleaned['InvoiceDate'].dt.date

# %%
rfm_cleaned.head()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 430882    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 430878    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 430879    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 430880    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 430881    536365     71053                  WHITE METAL LANTERN         6
#
#        InvoiceDate  UnitPrice CustomerID         Country
# 430882  2010-12-01       2.75      17850  United Kingdom
# 430878  2010-12-01       3.39      17850  United Kingdom
# 430879  2010-12-01       3.39      17850  United Kingdom
# 430880  2010-12-01       7.65      17850  United Kingdom
# 430881  2010-12-01       3.39      17850  United Kingdom

# %% [markdown]
# ## Step 4. Selecting date range for analysis by user prompt

# %% [markdown]
# ### Creating variables for min and max dates in the data set

# %% [markdown]
# Creating variable earliest_date, which will be allways the earliest date in the data set.

# %%
#getting the earliest date in data set to use in teh users promot
earliest_date = rfm_cleaned['InvoiceDate'].min()
earliest_date
# Out:
# datetime.date(2010, 12, 1)

# %% [markdown]
# Creating variable latest_date, which will be allways the latest date in the data set.

# %%
# getting the latest date in data set to use in the users prompt
latest_date = rfm_cleaned['InvoiceDate'].max()
latest_date
# Out:
# datetime.date(2011, 12, 9)

# %% [markdown]
# ### Creating info for user of the possible time range for analysis

# %%
# print info of min and max date using created earliest and latest date variables
print(f"The data set time range for RFM analysis is: {earliest_date} to {latest_date}.\n")
# Out:
# The data set time range for RFM analysis is: 2010-12-01 to 2011-12-09.

# %% [markdown]
# To create sensible analysis we will constraint the least possible period to be selected for analysis to 30 days.

# %%
#printing info for user of the least time period that can be selected for analysis
print("Select time period for analysis. The shortest possible analysis period is 30 days.\n")
# Out:
# Select time period for analysis. The shortest possible analysis period is 30 days.

# %% [markdown]
# ### Start date prompt

# %% [markdown]
# Creating input() to promot user for the start of the analysis.
#
# The input contains information of the earliest date and the latest date of possible date range selection.
#
# Because we want the user to select at least 30 days for the analysis, we will create start_date_constraint variable that will be latest date in the data set minus 30 days. Possible user selection for start date will be then constraint to be from earliest date in the data set to latest date in the data set minus 30 days, so that at least 30 days from strat date to end date will be possible for selection.

# %% [markdown]
# #### Creating start date constraint varible

# %%
#creating start date constraint to use in the prompt
start_date_constraint = latest_date - timedelta(days=30)
start_date_constraint
# Out:
# datetime.date(2011, 11, 9)

# %% [markdown]
# #### Creating a loop for user start date input:
# - we use earliest date in the data set and start_date_constraint variables in the input to indicate possible selection, and we indicate the required format for the input (YYYY-MM-DD),
#
# - we "try" to convert user's input from string to date type,
#
# - if the "try" is not successful (the input is in incorrect format), we use "except" to inform user about invalid date format and the code will loop the input() until correct format is entered,
#
# - if the correct format is entered the code will check, if the entered date is in the possible date selection (from earliest_date to start_date_constraint),
#
# - if enetered date is out of possible dates selection, the code will print info for user, that selected date is out of possible range and continue looping the input(),
#
# - the code will continue looping until the date is entered in the correct format and is in the possible date range caonstraint.

# %%
#creating wihle loop to loop until the user enters a date in the correct format and within the possible date range
while True:

    try:
      #prompt user for start date from earliest_date and latest_date (min and max date in the data set)
      start_date_prompt = input(f"Enter start date from: {earliest_date} to: {start_date_constraint} (format: YYYY-MM-DD): ")

      # converting users input from string to date format
      start_date_object = datetime.strptime(start_date_prompt.strip(), '%Y-%m-%d').date()

      print("Selected start date:", start_date_object)

    except ValueError:
      # printing info in case invalid format enetered
      print("Invalid date format. Please enter a date in the format YYYY-MM-DD.")
      continue

    # checking if the selected date is in the range of possible date selection (min date and max date in the data set)
    if start_date_object < earliest_date or start_date_object > start_date_constraint:
        print(f"Selected start date is out of possible range: {earliest_date} - {start_date_constraint}.")

    # break the loop if the users input is in the correct format and within the possible date range
    else:
        break
# Out:
# Enter start date from: 2010-12-01 to: 2011-11-09 (format: YYYY-MM-DD): khdkackdskcs
# Invalid date format. Please enter a date in the format YYYY-MM-DD.
# Enter start date from: 2010-12-01 to: 2011-11-09 (format: YYYY-MM-DD): 2009-01-01
# Selected start date: 2009-01-01
# Selected start date is out of possible range: 2010-12-01 - 2011-11-09.
# Enter start date from: 2010-12-01 to: 2011-11-09 (format: YYYY-MM-DD):      2010-12-01
# Selected start date: 2010-12-01

# %% [markdown]
# ### End date prompt

# %% [markdown]
# We apply the same solution for the end date prompt, except that the possible end date range selection will be from the start date selected by user (start_date_object variable created in the previous step) plus 30 days (so the selected date range is at least 30 days), to the latest date in the data set.

# %% [markdown]
# #### Creating end date constraint variable

# %%
#Creating end date constraint variable (selected start date + 30 days)
end_date_constraint = start_date_object + timedelta(days=30)

# %% [markdown]
# #### Creating a loop for user end date input:
# - we use end_date_constraint and latest_date variables in the input to indicate possible selection, and we indicate the required format for the input (YYYY-MM-DD),
#
# - we "try" to convert user's input from string to date type,
#
# - if the "try" is not successful (the input is in incorrect format), we use "except" to inform user about invalid date format and the code will loop the input() until correct format is entered,
#
# - if the correct format is entered the code will check, if the entered date is in the possible date selection (from end_date_constraint to latest_date in the data set),
#
# - if enetered date is out of possible dates selection, the code will print info for user, that selected date is out of possible range and continue looping the input(),
#
# - the code will continue looping until the date is entered in the correct format and is in the possible date range caonstraint.

# %%
#creating wihle loop to loop until the user enters a date in the correct format and within the possible date range
while True:

    try:
      #prompt user for end date from start date (selected already by user) and latest_date in the data set
      end_date_prompt = input(f"Enter end date from: {end_date_constraint} to {latest_date} (format: YYYY-MM-DD): ")

      # converting users input from string to date format
      end_date_object = datetime.strptime(end_date_prompt.strip(), '%Y-%m-%d').date()

      print("Selected end date:", end_date_object)

    except ValueError:
      # printing info in case invalid format enetered
      print("Invalid date format. Please enter a date in the format YYYY-MM-DD.")
      continue

    # checking if the selected date is in the range of possible  date selection (min date and max date in the data set)
    if end_date_object > latest_date or end_date_object < end_date_constraint:

        print(f"Selected end date: is out of possible range: {end_date_constraint} - {latest_date}")

    # break the loop if the users input is in the correct format and within the possible date range
    else:
        break
# Out:
# Enter end date from: 2010-12-31 to 2011-12-09 (format: YYYY-MM-DD): kdkhhdhwhdh
# Invalid date format. Please enter a date in the format YYYY-MM-DD.
# Enter end date from: 2010-12-31 to 2011-12-09 (format: YYYY-MM-DD): 2010-01-01
# Selected end date: 2010-01-01
# Selected end date: is out of possible range: 2010-12-31 - 2011-12-09
# Enter end date from: 2010-12-31 to 2011-12-09 (format: YYYY-MM-DD):      2011-12-09
# Selected end date: 2011-12-09

# %% [markdown]
# ### Creating data set with user's date range selection

# %%
#creating data set on selected data rane if valid data selection
rfm_filtered = rfm_cleaned[(rfm_cleaned['InvoiceDate'] >= start_date_object) & (rfm_cleaned['InvoiceDate'] <= end_date_object)]

# %%
rfm_filtered
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 430882    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 430878    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 430879    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 430880    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 430881    536365     71053                  WHITE METAL LANTERN         6
# ...          ...       ...                                  ...       ...
# 342461    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 342462    581587     22555            PLASTERS IN TIN STRONGMAN        12
# 342463    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 342457    581587     23256          CHILDRENS CUTLERY SPACEBOY          4
# 342450    581587     22728            ALARM CLOCK BAKELIKE PINK         4
#
#        InvoiceDate  UnitPrice CustomerID         Country
# 430882  2010-12-01       2.75      17850  United Kingdom
# 430878  2010-12-01       3.39      17850  United Kingdom
# 430879  2010-12-01       3.39      17850  United Kingdom
# 430880  2010-12-01       7.65      17850  United Kingdom
# 430881  2010-12-01       3.39      17850  United Kingdom
# ...            ...        ...        ...             ...
# 342461  2011-12-09       4.15      12680          France
# 342462  2011-12-09       1.65      12680          France
# 342463  2011-12-09       0.85      12680          France
# 342457  2011-12-09       4.15      12680          France
# 342450  2011-12-09       3.75      12680          France
#
# [401604 rows x 8 columns]

# %%
#checkig data distribution in the data set
rfm_filtered.describe(include='all')
# Out:
#        InvoiceNo StockCode                         Description    Quantity  \
# count     401604    401604                              401604    401604.0
# unique     22190      3684                                3896        <NA>
# top       576339    85123A  WHITE HANGING HEART T-LIGHT HOLDER        <NA>
# freq         542      2065                                2058        <NA>
# mean         NaN       NaN                                 NaN   12.183273
# std          NaN       NaN                                 NaN  250.283037
# min          NaN       NaN                                 NaN    -80995.0
# 25%          NaN       NaN                                 NaN         2.0
# 50%          NaN       NaN                                 NaN         5.0
# 75%          NaN       NaN                                 NaN        12.0
# max          NaN       NaN                                 NaN     80995.0
#
#        InvoiceDate      UnitPrice CustomerID         Country
# count       401604  401604.000000     401604          401604
# unique         305            NaN       4372              37
# top     2011-12-05            NaN      17841  United Kingdom
# freq          3359            NaN       7812          356728
# mean           NaN       3.474064        NaN             NaN
# std            NaN      69.764035        NaN             NaN
# min            NaN       0.000000        NaN             NaN
# 25%            NaN       1.250000        NaN             NaN
# 50%            NaN       1.950000        NaN             NaN
# 75%            NaN       3.750000        NaN             NaN
# max            NaN   38970.000000        NaN             NaN

# %% [markdown]
# ## Step 5. Calculating recency, frequency and monetary

# %% [markdown]
# ### Selecting columns for recency, frequency and monetary calculation

# %%
#filtering out columns for calulations of recency, frequency and monetary
rfm_transformed = rfm_filtered[['CustomerID', 'InvoiceDate', 'InvoiceNo', 'Quantity', 'UnitPrice']]
rfm_transformed.head()
# Out:
#        CustomerID InvoiceDate InvoiceNo  Quantity  UnitPrice
# 430882      17850  2010-12-01    536365         8       2.75
# 430878      17850  2010-12-01    536365         6       3.39
# 430879      17850  2010-12-01    536365         6       3.39
# 430880      17850  2010-12-01    536365         2       7.65
# 430881      17850  2010-12-01    536365         6       3.39

# %% [markdown]
# ### Creating Value column for monetary calculation (quantity * unit price)

# %%
# cerating Value column for calculation of monetary
rfm_transformed['Value'] = rfm_transformed['Quantity'] * rfm_transformed['UnitPrice']
# Out:
# <ipython-input-213-1de332122251>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
rfm_transformed.head()
# Out:
#        CustomerID InvoiceDate InvoiceNo  Quantity  UnitPrice  Value
# 430882      17850  2010-12-01    536365         8       2.75   22.0
# 430878      17850  2010-12-01    536365         6       3.39  20.34
# 430879      17850  2010-12-01    536365         6       3.39  20.34
# 430880      17850  2010-12-01    536365         2       7.65   15.3
# 430881      17850  2010-12-01    536365         6       3.39  20.34

# %% [markdown]
# ### Applying aggregations by CustomerID. Calculating Frequency and monetary.

# %%
#applying aggregations to receive:
# latest invoice (for calculation of recency),
# unique count of invoices - frequency
# sum of value - monetary
# for each customer
rfm_transformed = rfm_transformed.groupby('CustomerID').agg({'InvoiceDate': 'max', 'InvoiceNo': 'nunique', 'Value': 'sum'})
rfm_transformed.head()
# Out:
#            InvoiceDate  InvoiceNo    Value
# CustomerID
# 12346       2011-01-18          2      0.0
# 12347       2011-12-07          7   4310.0
# 12348       2011-09-25          4  1797.24
# 12349       2011-11-21          1  1757.55
# 12350       2011-02-02          1    334.4

# %%
#renaming the columns for clarity
rfm_transformed.columns = ['LatestInvoice', 'Frequency', 'Monetary']
rfm_transformed.head()
# Out:
#            LatestInvoice  Frequency  Monetary
# CustomerID
# 12346         2011-01-18          2       0.0
# 12347         2011-12-07          7    4310.0
# 12348         2011-09-25          4   1797.24
# 12349         2011-11-21          1   1757.55
# 12350         2011-02-02          1     334.4

# %% [markdown]
# ### Calculating recency

# %%
#calculating recency in days
today = pd.to_datetime(rfm_filtered['InvoiceDate'].max())
today
# Out:
# Timestamp('2011-12-09 00:00:00')

# %%
rfm_transformed['LatestInvoice'] = pd.to_datetime(rfm_transformed['LatestInvoice'], errors='coerce')
rfm_transformed.dtypes
# Out:
# LatestInvoice    datetime64[ns]
# Frequency                 int64
# Monetary                Float64
# dtype: object

# %%
rfm_transformed['Recency'] = (today - rfm_transformed['LatestInvoice']).dt.days
rfm_transformed.head()
# Out:
#            LatestInvoice  Frequency  Monetary  Recency
# CustomerID
# 12346         2011-01-18          2       0.0      325
# 12347         2011-12-07          7    4310.0        2
# 12348         2011-09-25          4   1797.24       75
# 12349         2011-11-21          1   1757.55       18
# 12350         2011-02-02          1     334.4      310

# %% [markdown]
# ### Creating table with recency, frequency and monetary values

# %%
# creating final table with calculation of recency, frequency and monetary
rfm_values = rfm_transformed[['Recency', 'Frequency', 'Monetary']]
rfm_values.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346           325          2       0.0
# 12347             2          7    4310.0
# 12348            75          4   1797.24
# 12349            18          1   1757.55
# 12350           310          1     334.4

# %% [markdown]
# ### Filtering out customers with negative and 0 monetary

# %%
#checking values distribution in rfm_values table
rfm_values.describe() # customers with monetary <0 should be filtered out
# Out:
#            Recency    Frequency     Monetary
# count  4372.000000  4372.000000       4372.0
# mean     91.581199     5.075480  1893.531433
# std     100.772139     9.338754  8218.696204
# min       0.000000     1.000000     -4287.63
# 25%      16.000000     1.000000      291.795
# 50%      50.000000     3.000000       644.07
# 75%     143.000000     5.000000     1608.335
# max     373.000000   248.000000    279489.02

# %%
#checking number of rows
rfm_values.shape
# Out:
# (4372, 3)

# %%
#filtering out custmerID's with monetary < 0
rfm_values_filtered = rfm_values[(rfm_values['Monetary'] > 0)]
rfm_values_filtered.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12347             2          7    4310.0
# 12348            75          4   1797.24
# 12349            18          1   1757.55
# 12350           310          1     334.4
# 12352            36         11   1545.41

# %%
#checkig distrbution in the filtered data set
rfm_values_filtered.describe() #negative Monetary values have been filtered out
# Out:
#            Recency    Frequency     Monetary
# count  4322.000000  4322.000000       4322.0
# mean     89.885932     5.115687  1918.498048
# std      99.132246     9.384459  8262.489661
# min       0.000000     1.000000          0.0
# 25%      16.000000     1.000000     300.5975
# 50%      49.000000     3.000000      653.325
# 75%     138.000000     6.000000    1624.1175
# max     373.000000   248.000000    279489.02

# %%
#checking dtypes in the table
rfm_values_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4322 entries, 12347 to 18287
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    4322 non-null   int64
#  1   Frequency  4322 non-null   int64
#  2   Monetary   4322 non-null   Float64
# dtypes: Float64(1), int64(2)
# memory usage: 139.3+ KB

# %%
#checking numebr of instances in the table
rfm_values_filtered.shape
# Out:
# (4322, 3)

# %% [markdown]
# ## Step 6. Visualization of recency, frequency and monetary values distribution

# %% [markdown]
# ### Setting up Python enviroment for data visualisation

# %%
#setting up enviroment, we will use plotly.express for visualisation
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
print('Setup complete')
# Out:
# Setup complete

# %% [markdown]
# ### Printing title for visualisations

# %%
#printing title
print(f"Recency, Frequency and Monetary values distribution in the period of: {start_date_object} - {end_date_object}:\n")
# Out:
# Recency, Frequency and Monetary values distribution in the period of: 2010-12-01 - 2011-12-09:

# %% [markdown]
# ### Creating boxplot and histogram for Recency

# %%
# Cearing boxplot and histogram for recency
fig1 = px.box(rfm_values_filtered, y='Recency')
fig2 = px.histogram(rfm_values_filtered, x='Recency')

# Createing grid subplots with 1 row and two columns
fig = make_subplots(rows=1, cols=2,
                    subplot_titles=('Box Plot of Recency', 'Histogram of Recency with Qauartiles'))

# adding recency box plot to the first subplot
for trace in fig1.data:
    #trace.line.color = 'green' - to change plot's color
    fig.add_trace(trace, row=1, col=1)

# Add recency histogram to the second subplot
for trace in fig2.data:
    fig.add_trace(trace, row=1, col=2)

# Update layout
fig.update_layout(title='Recency values distribution',
                  showlegend=False)

# Update yaxis label for the box plot
fig.update_yaxes(title_text='Recency in days', row=1, col=1)

# Update yaxis label for the histogram
fig.update_yaxes(title_text='Number of customers', row=1, col=2)

# update xasis label for the histogram
fig.update_xaxes(title="Recency in days", row=1, col=2)

# Compute quartiles
quartiles = np.percentile(rfm_values_filtered['Recency'], [25, 50, 75])

# Add vertical lines for quartiles
for q in quartiles:
    fig.add_vline(x=q, line=dict(color="black", width=1, dash="dash"), row=1, col=2)

# Show figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1419fa55-4d05-43cf-8022-a68cb1d7cbd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1419fa55-4d05-43cf-8022-a68cb1d7cbd3")) {                    Plotly.newPlot(                        "1419fa55-4d05-43cf-8022-a68cb1d7cbd3",                        [{"alignmentgroup":"True","hovertemplate":"Recency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[2,75,18,310,36,204,232,214,22,33,1,7,52,287,3,109,7,291,4,51,44,71,311,25,2,315,129,81,21,4,184,28,337,15,79,21,72,63,15,35,45,119,303,323,49,148,22,49,32,78,301,74,66,217,24,3,112,63,15,95,0,162,78,194,11,25,9,43,35,42,0,84,79,99,1,14,366,3,21,22,57,243,44,22,156,10,16,134,73,44,58,71,94,2,46,10,7,143,2,30,29,17,53,1,22,3,3,28,22,17,32,9,336,5,38,63,165,9,81,21,23,315,95,18,232,134,26,284,142,66,84,267,353,77,28,0,63,79,142,39,1,9,0,81,9,59,14,30,130,91,7,29,22,19,29,29,75,46,197,166,79,357,38,8,50,16,310,5,302,8,261,281,72,22,2,39,8,227,315,35,35,21,73,246,39,238,2,3,234,17,7,39,28,190,317,92,108,37,51,19,9,29,28,189,58,21,79,78,22,52,57,31,277,2,85,29,21,16,14,1,232,276,106,211,23,10,4,9,57,58,89,67,33,238,23,115,25,128,129,33,4,22,154,107,3,334,322,148,10,17,11,18,29,11,0,8,324,58,7,150,10,329,5,11,24,42,52,0,14,3,4,7,28,371,113,25,205,28,120,70,7,21,7,79,19,64,7,15,291,29,3,96,22,0,9,106,3,151,71,5,2,31,85,3,5,371,28,10,71,113,23,179,234,352,315,332,372,78,63,134,51,2,0,3,128,81,3,235,249,86,15,116,52,7,138,316,3,238,210,59,17,19,21,21,4,2,9,2,9,65,192,373,256,334,53,18,360,10,183,36,168,260,44,101,147,95,281,178,3,214,70,74,59,2,5,2,322,37,262,32,145,282,59,173,33,2,143,4,70,65,29,267,22,31,96,290,107,78,372,7,210,52,138,26,283,26,185,84,326,282,143,57,3,18,44,275,9,24,88,63,67,214,24,185,30,42,204,8,264,18,11,58,39,23,2,4,148,138,128,8,17,3,161,64,88,4,35,122,78,21,24,2,17,15,25,64,46,131,35,288,143,16,30,2,8,5,9,1,306,4,7,8,89,9,3,112,7,3,197,211,156,155,29,239,18,0,73,292,3,31,23,23,4,77,22,196,106,4,318,105,11,173,56,323,372,9,1,2,53,73,7,16,4,64,1,113,22,30,11,38,357,54,57,138,80,8,253,291,99,30,31,14,64,9,212,64,24,249,253,72,191,12,373,24,82,10,0,192,266,129,1,1,4,179,1,126,4,157,2,8,21,70,267,21,70,32,1,99,234,1,39,3,128,44,372,2,31,0,8,117,21,19,238,269,94,89,4,77,94,23,261,273,72,196,50,10,22,16,108,84,19,332,39,26,10,29,14,203,5,33,49,94,8,22,313,122,46,282,18,36,63,26,8,4,16,46,64,26,45,7,14,267,39,337,11,18,95,61,135,11,10,3,19,9,15,58,30,93,10,9,56,267,122,127,78,240,200,60,3,273,201,81,225,4,12,74,211,24,11,261,96,112,203,92,50,18,17,124,92,156,3,11,61,61,268,263,1,53,11,2,17,1,366,37,31,113,63,15,40,64,122,18,59,322,23,155,38,189,359,137,7,1,268,164,103,155,351,4,120,22,7,8,4,22,1,37,64,1,5,70,72,17,3,32,81,38,316,31,92,14,82,77,154,200,45,260,172,67,276,70,64,10,16,66,7,71,122,80,257,268,59,3,17,66,8,50,256,354,366,89,60,81,99,26,21,280,30,329,121,11,74,203,1,185,21,72,192,127,17,1,74,1,8,107,133,43,4,11,63,134,40,51,108,0,19,10,10,18,67,74,5,1,14,255,91,23,16,23,26,26,259,165,24,17,7,29,38,183,58,100,10,1,99,1,60,236,191,178,37,198,45,232,65,241,233,78,57,17,105,51,136,275,311,7,10,282,17,23,242,16,71,64,67,312,3,243,8,1,260,126,73,72,21,59,85,50,58,1,30,33,40,14,33,78,205,33,182,2,1,43,85,39,12,96,25,319,66,73,28,5,7,215,81,84,144,19,40,173,17,243,12,205,50,23,10,25,14,309,155,306,31,15,14,11,64,35,108,52,5,47,1,312,45,64,26,29,40,12,89,24,312,40,173,116,30,252,59,23,5,99,24,33,67,36,52,15,74,215,31,8,120,9,256,16,35,45,43,114,164,10,9,197,85,179,60,149,2,50,75,18,151,151,1,17,187,285,2,182,63,59,24,3,31,38,155,26,318,5,7,302,267,271,3,31,218,246,281,269,32,246,15,116,36,120,217,49,38,28,36,135,219,28,24,5 ...

# %% [markdown]
# ### Creating boxplot and histogram for Frequency

# %%
# Cearing boxplot and histogram for frequency
fig1 = px.box(rfm_values_filtered, y='Frequency')
fig2 = px.histogram(rfm_values_filtered, x='Frequency')

# Createing grid subplots with 1 row and two columns
fig = make_subplots(rows=1, cols=2,
                    subplot_titles=('Box Plot of Frequency', 'Histogram of Frequncy with Qauartiles'))

# adding recency box plot to the first subplot
for trace in fig1.data:
    fig.add_trace(trace, row=1, col=1)

# Add recency histogram to the second subplot
for trace in fig2.data:
    fig.add_trace(trace, row=1, col=2)

# Update layout
fig.update_layout(title='Frequency values distribution',
                  showlegend=False)

# Update yaxis label for the box plot
fig.update_yaxes(title_text='Frequency (number of orders)', row=1, col=1)

# Update yaxis label for the histogram
fig.update_yaxes(title_text='Number of customers', row=1, col=2)

# update xasis label for the histogram
fig.update_xaxes(title='Frequency (number of orders)', row=1, col=2)

# Compute quartiles
quartiles = np.percentile(rfm_values_filtered['Frequency'], [25, 50, 75])

# Add vertical lines for quartiles
for q in quartiles:
    fig.add_vline(x=q, line=dict(color="black", width=1, dash="dash"), row=1, col=2)

# Show figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="390db782-a4d1-435c-afb6-ec3a2316d830" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("390db782-a4d1-435c-afb6-ec3a2316d830")) {                    Plotly.newPlot(                        "390db782-a4d1-435c-afb6-ec3a2316d830",                        [{"alignmentgroup":"True","hovertemplate":"Frequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[7,4,1,1,11,1,1,1,3,1,2,6,3,1,13,2,4,3,1,4,2,3,1,1,3,2,1,3,5,6,6,3,2,6,1,1,4,2,15,2,1,4,1,1,2,1,3,5,9,7,3,3,5,3,26,12,1,1,5,3,9,2,1,1,5,12,4,1,18,5,7,4,2,1,19,2,1,1,5,1,1,1,1,4,2,6,3,1,6,4,12,2,2,4,7,8,3,3,49,13,9,30,1,20,9,1,3,4,11,13,8,3,1,10,1,2,3,13,1,3,13,2,5,4,1,4,2,1,2,2,2,1,1,2,6,5,1,6,1,2,13,8,3,3,8,5,1,1,1,2,5,1,5,19,3,2,2,3,2,1,1,1,2,14,2,5,3,4,1,7,1,2,2,11,35,2,3,1,1,6,4,4,3,1,1,2,18,18,4,2,1,1,2,3,1,2,3,11,2,5,9,7,11,6,1,1,2,3,7,1,2,6,1,4,5,1,1,13,3,23,1,1,2,3,13,7,4,2,1,5,2,10,1,1,3,1,3,6,1,5,2,13,1,4,1,1,2,2,5,8,5,1,1,1,12,10,2,1,6,4,6,1,2,7,6,13,9,4,27,31,20,7,6,1,1,2,1,6,6,2,4,5,6,2,1,2,10,14,1,16,26,4,17,1,5,1,2,3,1,3,29,7,6,5,4,1,7,9,4,1,14,1,1,1,2,1,1,2,1,2,10,11,224,8,1,1,11,5,4,1,19,2,3,2,2,1,7,1,1,1,6,7,12,5,6,8,2,2,3,1,1,1,1,2,2,1,3,3,2,3,2,3,1,1,2,2,1,2,4,1,3,5,1,8,3,6,3,7,1,2,1,1,4,1,2,16,6,26,2,9,2,4,1,2,1,2,9,5,1,8,2,2,1,3,1,10,6,2,2,1,2,2,12,3,4,1,2,4,1,4,3,4,1,3,1,3,2,36,1,2,5,4,8,8,5,5,2,5,1,8,1,50,1,1,5,2,5,2,4,20,4,8,5,4,1,8,4,3,2,1,11,8,10,3,8,5,1,14,1,12,2,9,1,1,4,1,4,89,1,1,1,12,2,2,1,3,3,1,19,3,2,4,5,2,7,3,3,15,1,3,22,3,1,2,1,11,15,16,5,3,1,29,12,2,8,6,3,3,2,3,1,2,3,3,3,2,2,1,1,2,18,5,2,28,1,4,3,1,1,1,1,4,1,3,1,2,27,1,1,1,4,43,5,1,21,10,2,3,118,18,2,6,13,16,1,14,41,1,1,27,1,6,2,5,1,5,8,40,14,2,8,7,1,2,2,3,10,1,1,4,1,2,7,1,11,9,6,8,3,6,1,1,5,1,4,17,4,2,1,4,5,4,5,1,1,5,2,2,4,5,2,1,5,2,3,1,1,11,1,9,12,1,5,1,1,2,2,1,1,4,8,39,4,4,2,7,11,1,3,4,6,1,5,1,4,2,2,3,8,1,1,1,1,15,7,2,2,3,5,1,4,3,1,1,1,7,4,2,3,2,3,3,1,1,2,1,35,5,19,27,15,17,1,2,2,1,2,4,1,2,3,6,2,2,4,1,2,2,2,1,4,1,1,2,4,1,1,10,1,4,5,6,2,5,4,5,9,3,36,6,2,1,5,12,1,9,1,4,3,1,3,1,3,1,7,1,2,3,2,1,1,1,3,1,2,1,1,1,1,1,2,5,2,2,3,1,2,2,2,1,3,2,3,3,7,1,9,1,3,3,1,1,10,1,4,6,1,2,1,2,3,81,7,1,3,2,2,23,1,4,3,2,3,12,3,1,4,4,2,2,9,1,7,1,1,4,10,1,6,6,2,2,4,7,22,2,3,2,1,2,2,41,2,4,3,1,4,4,8,3,8,1,1,1,1,3,3,17,4,10,3,2,1,6,3,3,7,4,2,3,1,1,8,3,4,1,7,5,1,1,1,4,3,5,1,2,8,3,1,6,5,2,8,2,2,1,3,43,7,7,4,2,3,2,8,1,16,4,2,4,1,1,3,2,5,2,2,1,2,1,12,1,2,5,20,5,2,1,1,1,3,13,2,7,3,4,6,1,2,2,33,1,2,1,1,3,1,9,4,4,2,3,1,1,7,1,7,11,11,12,6,5,1,6,3,1,1,1,3,5,1,5,2,7,2,3,6,2,2,2,7,3,7,1,3,1,29,2,1,2,2,1,5,4,1,2,7,1,1,1,5,60,15,1,1,10,1,10,3,1,2,1,17,1,2,1,8,1,7,2,5,4,1,4,1,11,2,2,6,2,2,1,8,3,1,1,1,4,14,8,2,2,1,5,5,1,6,1,2,10,15,7,2,2,2,2,3,3,52,16,5,3,1,41,1,2,1,6,11,1,2,1,3,2,63,2,1,1,6,1,7,2,1,1,5,1,4,4,3,5,3,5,4,2,3,2,2,2,5,2,3,1,6,2,1,4,2,4,1,9,1,1,4,3,2,2,3,2,29,5,1,1,6,10,2,4,1,3,2,4,10,14,4,1,5,1,1,1,13,22,6,9,6,2,1,1,2,1,14,4,1,5,5,1,1,2,3,5,2,5,9,3,2,2,3,1,1,11,6,1,1,4,3,2,3,1,2,1,2,1,1,4,4,7,3,1,1,6,5,3,3,7,3,2,5,3,2,2,4,1,20,11,2,1,1,7,1,2,1,1,5,13,6,16,1,9,2,1,7,1,12,6,6,15,2,4,2,7,5,3,3,1,3,1,1,5,4,2,3,1,2,2,1,2,8,23,18,4,5,1,2,4,1,15,1,4,4,1,7,2,6,2,26,1,2,1,1,29,18,1,20,12,7,1,2,1,9,2,3,1,5,6,1,1,4,1,9,19,2,14,1,1,17,1,34,1,12,1,6,8,2,2,8,3,2,13,5,12,8,2,5,1,6,1,3,4,3,2,5,1,12,5,15,2,1,3,6,1,1,5,6,3,1,3,2,3,2,1,66,3,1,14,3,2,4,2,1,4,1,4,1,7,5,5,7,2,31,1,1,10,24,14,2,32,3,1,7,1,9,1,4,2,1,7,7,13,1,7,7,4,24,1,1,2,10,1,4,4,7,15,5,5,8,5,4,6,2,1,1,13,2,1,2,14,5,3,1,1,3,5,3,6,10,1,2,8,3,2,7,1,1,2,4,5,4,1,15,3,4,5,4,2,6,6,12,14,4,2,6,45,18,1,2,2,5,3,6,10,2,6,1,7,1,3,5,4,2,1,14,2,3,2,9,2,4,4,4,1,9,6,8,1,2,1,1,2,1,4,1,2,1,4,1,6,4,1,8,19,1,1,1,1,2,2,1,1,3,3,1,3,10,5,13,1,12,2, ...

# %% [markdown]
# ### Creating boxplot and histogram for Monetary

# %%
# Crearing boxplot and histogram for monetary
fig1 = px.box(rfm_values_filtered, y='Monetary')
fig2 = px.histogram(rfm_values_filtered, x='Monetary')

# Createing grid subplots with 1 row and two columns
fig = make_subplots(rows=1, cols=2,
                    subplot_titles=('Box Plot of Monetary', 'Histogram of Monetary with Qauartiles'))

# adding recency box plot to the first subplot
for trace in fig1.data:
    fig.add_trace(trace, row=1, col=1)

# Add recency histogram to the second subplot
for trace in fig2.data:
    fig.add_trace(trace, row=1, col=2)

# Update layout
fig.update_layout(title='Monetary values distribution',
                  showlegend=False)

# Update yaxis label for the box plot
fig.update_yaxes(title_text='Monetary (value of sales in EUR)', row=1, col=1)

# Update yaxis label for the histogram
fig.update_yaxes(title_text='Number of customers', row=1, col=2)

# update xasis label for the histogram
fig.update_xaxes(title='Monetary (value of sales in EUR)', row=1, col=2)

# Compute quartiles
quartiles = np.percentile(rfm_values_filtered['Monetary'], [25, 50, 75])

# Add vertical lines for quartiles
for q in quartiles:
    fig.add_vline(x=q, line=dict(color="black", width=1, dash="dash"), row=1, col=2)

# Show figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0ff267cf-53f4-4aa3-a8af-ac0bc4695fb6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ff267cf-53f4-4aa3-a8af-ac0bc4695fb6")) {                    Plotly.newPlot(                        "0ff267cf-53f4-4aa3-a8af-ac0bc4695fb6",                        [{"alignmentgroup":"True","hovertemplate":"Monetary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[4310.0,1797.24,1757.55,334.4,1545.41,89.0,1079.4,459.4,2811.43,6207.67,1168.06,6182.9800000000005,2662.06,189.9,5154.58,552.0,1313.1,320.69,168.9,3541.94,1887.96,1298.04,364.6,742.9300000000001,455.42,1628.12,4008.62,850.29,2720.56,1803.96,1839.31,566.16,401.9,2780.66,549.84,439.66,1582.6000000000001,1272.48,2998.28,2409.9,1635.66,1108.65,84.3,225.6,409.7,1710.39,3280.75,1708.1200000000001,2842.57,11056.93,681.08,1226.88,694.15,562.41,123725.45,3578.8,668.58,600.39,806.27,803.5600000000001,1849.11,1760.96,777.2,582.73,708.37,7877.2,3750.4,256.4,6348.89,5059.32,13375.87,765.19,7829.89,509.01,4896.66,2906.85,173.55,172.06,5005.46,133.4,1002.3100000000001,476.49,449.45,4067.29,197.88,8933.52,428.57,707.09,2466.86,3153.89,1917.78,947.4,826.88,1124.01,1303.63,1212.05,733.89,724.0400000000001,18705.52,6229.48,2837.73,7064.7699999999995,723.38,6546.58,13117.01,680.99,477.3,3281.63,5574.36,2327.13,4480.87,1298.66,334.93,5417.93,460.40000000000003,263.21000000000004,416.79,1139.3500000000001,1043.1,403.70000000000005,4206.2699999999995,2089.68,3723.87,114.0,73.5,1258.06,397.88,176.5,982.5699999999999,132.18,586.79,1017.68,383.7,1312.06,2443.65,2056.89,330.84,2582.51,599.68,192.72,1745.57,4485.72,1316.66,348.71000000000004,1922.28,1623.63,125.22,349.83000000000004,1089.18,716.35,4106.82,363.95,3852.5,13309.039999999999,981.18,355.7,1000.39,1141.5,207.79999999999998,95.19999999999999,964.8299999999999,168.0,437.82,3652.25,599.56,11990.96,536.21,2101.39,238.85,3781.74,456.9,131.17,346.7,9114.94,4064.9900000000002,519.61,1004.72,160.54000000000002,218.45000000000002,1306.98,564.2,2753.36,410.71999999999997,415.7,197.71,511.36,7187.34,1893.95,1982.81,179.94,144.0,214.89999999999998,646.68,9861.38,452.85,437.6,418.09999999999997,3320.2200000000003,618.27,3683.13,3002.68,1032.58,2581.04,569.5600000000001,153.12,739.1999999999999,254.18,1126.85,2057.99,1193.32,643.59,3218.98,315.6,2291.19,657.25,352.98,177.31,3214.81,1339.41,13612.07,180.1,305.1,641.13,2614.32,6388.35,4478.53,769.61,1270.88,640.5,2140.63,1689.18,5934.25,671.69,486.1,1174.58,185.89999999999998,1013.26,3344.64,477.91,1755.38,1346.97,3669.92,318.05,603.71,314.44,114.0,914.53,2209.85,601.98,3982.72,1152.06,686.05,91.68,245.1,3817.08,4863.88,61.75,620.13,3743.18,1607.73,2986.15,225.9,610.52,1922.26,1331.39,17588.26,1058.67,862.81,13677.59,12279.82,8221.09,2283.63,2863.08,89.14,4873.81,1247.61,389.01,1035.8,830.96,869.67,582.1,939.02,4867.99,797.71,219.0,274.7,2220.84,6814.24,603.42,2616.32,9264.1,1130.57,4241.63,848.55,4708.86,343.36,1053.49,980.98,238.25,608.1,5713.28,2628.98,904.33,725.07,1031.41,427.8,2609.1,3947.7,836.33,453.01,18793.41,236.26,383.95,110.39999999999999,779.5699999999999,234.0,155.35,1013.04,427.6,540.13,9120.39,4196.01,28405.56,3868.2,275.88,4366.78,21024.01,2949.12,2203.2,112.07999999999998,4205.25,2791.59,1531.44,1898.52,494.08,1693.88,6989.63,1143.6,1351.45,892.47,1351.24,804.23,3868.7,707.72,2273.32,1603.87,532.8199999999999,305.71,463.65999999999997,91.85,324.92,192.60000000000002,400.53999999999996,545.48,860.41,430.48,194.18,6977.04,412.58000000000004,483.65000000000003,484.36,514.85,229.64000000000001,125.92,1063.46,572.2,166.04,1517.88,942.34,92.72,918.98 ...

# %%
rfm_values_filtered.describe()
# Out:
#            Recency    Frequency     Monetary
# count  4322.000000  4322.000000       4322.0
# mean     89.885932     5.115687  1918.498048
# std      99.132246     9.384459  8262.489661
# min       0.000000     1.000000          0.0
# 25%      16.000000     1.000000     300.5975
# 50%      49.000000     3.000000      653.325
# 75%     138.000000     6.000000    1624.1175
# max     373.000000   248.000000    279489.02

# %% [markdown]
# ## Step 7. Applying RFM score

# %% [markdown]
# ### Applying recency score

# %% [markdown]
# Recency score is caculated using quartiles. Customers who ordered most recent are labeled "4" for recency score, customers who ordered latest are labeled "1" for recency score.

# %%
#creating column for recency score and applying quartiles to divide customers into 4 bins
rfm_values_filtered['R_score'] = pd.qcut(rfm_values_filtered['Recency'], q=4, labels=range(4, 0, -1)).astype(str)
# we apply backward lablels here so that customers who orderd most recent are labeled 4 for R_score
# Out:
# <ipython-input-233-1cf43e23b1de>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Applying frequency score

# %% [markdown]
# For frequency score we need to define custom bins, because the data is not evenly distributed. Most clients ordered only once, so have frequency 1. We need to define custom bins, so that clients with similar behaviour get thesame freqency score.

# %% [markdown]
# We define four custom bins with the following labels:
#
# "1" - customers with frequency 0 to 1 (included)
#
# "2" - customers with frequency 1 to 3 (included) as the 2nd quartile for frequency is 3
#
# "3" - customers with frequency 3 to 6 (included) as the 3rd quartile for frequency is 6
#
# "4" - customers with frequency over 6

# %%
#Creating custom bins: (0-1), (1-3), (3-6), (6 to positive infinity)
frequency_bins = [0, 1, 3, 6, np.inf]

# Defining labels for bins (n-1 bins)
frequency_labels = [1, 2, 3, 4]

# Creating a new column with the custom bin labels
rfm_values_filtered['F_score'] = pd.cut(rfm_values_filtered['Frequency'], bins=frequency_bins, labels=frequency_labels).astype(str)
# Out:
# <ipython-input-234-5cb2cc4a2a45>:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Applying monetary score

# %% [markdown]
# Mnatary score is caculated using quartiles. Customers with highest monetary (highest sales values) are labeled "4" for monetary score, customers with lowest monetary (lowest sales values) are labeled "1" for monetary score.

# %%
# creating new column with monetary score and applyin quartiles to divide customers into 4 bins
rfm_values_filtered['M_score'] = pd.qcut(rfm_values_filtered['Monetary'], q=4, labels=range(1, 5)).astype(str)
# customers are labeled 4 for higest monetary 1 for lowest monetary
# Out:
# <ipython-input-235-49f7b6c8cce1>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Creating RFM score

# %%
# selecting columns for creating RFM score
rfm_scores = rfm_values_filtered[['Recency', 'Frequency', 'Monetary', 'R_score', 'F_score', 'M_score']]
rfm_scores.head()
# Out:
#             Recency  Frequency  Monetary R_score F_score M_score
# CustomerID
# 12347             2          7    4310.0       4       4       4
# 12348            75          4   1797.24       2       3       4
# 12349            18          1   1757.55       3       1       4
# 12350           310          1     334.4       1       1       2
# 12352            36         11   1545.41       3       4       3

# %%
#checking data types
rfm_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4322 entries, 12347 to 18287
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    4322 non-null   int64
#  1   Frequency  4322 non-null   int64
#  2   Monetary   4322 non-null   Float64
#  3   R_score    4322 non-null   object
#  4   F_score    4322 non-null   object
#  5   M_score    4322 non-null   object
# dtypes: Float64(1), int64(2), object(3)
# memory usage: 240.6+ KB

# %%
#creating column with RFM score
rfm_scores['RFM_score'] = rfm_scores['R_score'] + rfm_scores['F_score'] +rfm_scores['M_score']

# %%
rfm_scores.head()
# Out:
#             Recency  Frequency  Monetary R_score F_score M_score RFM_score
# CustomerID
# 12347             2          7    4310.0       4       4       4       444
# 12348            75          4   1797.24       2       3       4       234
# 12349            18          1   1757.55       3       1       4       314
# 12350           310          1     334.4       1       1       2       112
# 12352            36         11   1545.41       3       4       3       343

# %% [markdown]
# ## Step 8. Defining Segments

# %% [markdown]
# ### Importing google sheet with defined Segments

# %% [markdown]
# Please note that this point is added only to display Segments description, that was prepared separately in googlesheet stored in personal drive. If you want to run the code from your enviroment, please "comment" this part, so that the remaining code (from "Creating column with segment name") could properly run in your enviromet.

# %%
import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
#select the file to load
worksheet = gc.open('RFM Segments description_pdanil').sheet1

# %%
# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
segments_description = pd.DataFrame.from_records(rows)

#setting column names from first row
segments_description.columns = segments_description.iloc[0]

# removing first row
segments_description = segments_description[1:]
segments_description
# Out:
# 0               Segment                                    RFM score range  \
# 1        Best customers                                                444
# 2       Loyal customers                  443, 344, 343, 442, 441, 342, 334
# 3   Potential loyalists                       434, 433, 424, 423, 432, 431
# 4      Recent customers                            422, 412, 421, 413, 411
# 5     Needing attention   333, 332, 331, 324, 323, 322, 321, 313, 312, 311
# 6               At risk        224, 233, 232, 243, 244, 234, 242, 231, 223
# 7          Big spenders                                 414, 314, 214, 114
# 8        About to sleep  222, 221, 211, 213, 212, 142, 141, 132, 131, 1...
# 9       Can't lose them                       134, 144, 133, 143, 124, 123
# 10       Lost customers                                                111
#
# 0                                         Description  \
# 1   Highly engaged customers, who have bought the ...
# 2   Customers who buy the most often and spent a g...
# 3   Recent customers, spent a good amount and boug...
# 4    Customers who bought most recently but not often
# 5   Customers above average recency and frequency ...
# 6   Customers who, made biggest purchases, often, ...
# 7   Customers who have generated the most revenue ...
# 8   Customers below average recency frequency and ...
# 9   Customers who spent above average amount of mo...
# 10  Customers with lowest recency, frequency and m...
#
# 0                                Marketing strategies
# 1   Focus on loyalty programs and new product intr...
# 2   Loyalty programs are effective for these repea...
# 3   Offer membership, loyalty program, recommended...
# 4   Provide on-boarding support. Give them early s...
# 5   Dedicated offers based on previous orders, lim...
# 6   Send personalized emails to reconnect. Offer r...
# 7   These customers have demonstrated a high willi...
# 8   Share valuable resources. Recommend popular pr...
# 9   Win them back by renewals or new products. Rea...
# 10  Revive interest with reach out campaign. Ignor...

# %% [markdown]
# ### Creating column with segment name

# %%
# Defining conditions and corresponding segment labels
conditions = [
    (rfm_scores['RFM_score'] == '444'),
    (rfm_scores['RFM_score'] == '111'),
    (rfm_scores['RFM_score'].isin(['222', '221', '213', '212', '211', '142', '141', '132', '131', '122', '121', '113', '112'])),
    (rfm_scores['RFM_score'].isin(['244','243','242','234','233','232','231','224','223'])),
    (rfm_scores['RFM_score'].isin(['414', '314', '214', '114'])),
    (rfm_scores['RFM_score'].isin(['144','143','134','133','124','123'])),
    (rfm_scores['RFM_score'].isin(['443', '442', '441', '344', '343', '342', '334'])),
    (rfm_scores['RFM_score'].isin(['434','433','432','431','424','423'])),
    (rfm_scores['RFM_score'].isin(['422', '421', '413', '412', '411']))]

segment_labels = [
    'Best customers',
    'Lost customers',
    'About to sleep',
    'At risk',
    'Big spenders',
    "Can't lose them",
    'Loyal customers',
    'Potential loyalists',
    'Recent customers']

# Creating the Segment column based on the conditions and segment labels
rfm_scores['Segment'] = np.select(conditions, segment_labels, default='Needing attention')

# %%
rfm_scores.head(10)
# Out:
#             Recency  Frequency  Monetary R_score F_score M_score RFM_score  \
# CustomerID
# 12347             2          7    4310.0       4       4       4       444
# 12348            75          4   1797.24       2       3       4       234
# 12349            18          1   1757.55       3       1       4       314
# 12350           310          1     334.4       1       1       2       112
# 12352            36         11   1545.41       3       4       3       343
# 12353           204          1      89.0       1       1       1       111
# 12354           232          1    1079.4       1       1       3       113
# 12355           214          1     459.4       1       1       2       112
# 12356            22          3   2811.43       3       2       4       324
# 12357            33          1   6207.67       3       1       4       314
#
#                       Segment
# CustomerID
# 12347          Best customers
# 12348                 At risk
# 12349            Big spenders
# 12350          About to sleep
# 12352         Loyal customers
# 12353          Lost customers
# 12354          About to sleep
# 12355          About to sleep
# 12356       Needing attention
# 12357            Big spenders

# %% [markdown]
# ## Step 9. RFM analysis and visualization

# %% [markdown]
# ### Aggregating data by Segment

# %%
#applying aggregation by segments
rfm_analysis = rfm_scores.groupby('Segment').agg(
    {'Segment': 'count', 'Recency': ['min', 'max', 'mean'], 'Frequency': ['min', 'max', 'mean'], 'Monetary': ['min', 'max', 'mean', 'sum']})

#rounding floating values and sorting by sum of monetary in descending order
rfm_analysis = rfm_analysis.round(1).sort_values(by=('Monetary', 'sum'), ascending=False)
rfm_analysis
# Out:
#                     Segment Recency             Frequency            Monetary  \
#                       count     min  max   mean       min  max  mean      min
# Segment
# Best customers          442       0   16    5.9         7  248  20.1   1632.4
# Loyal customers         399       0   49   24.9         4   76   9.9    191.2
# At risk                 499      50  138   80.8         2   20   4.9    102.0
# Potential loyalists     368       0   16    7.4         2    6   4.3    151.2
# Needing attention       747      17   72   30.1         1    7   2.6      0.0
# About to sleep         1087      50  373  156.7         1    9   1.7      0.0
# Can't lose them         152     140  366  206.8         2   35   4.2    658.3
# Recent customers        212       0   16    8.1         1    3   1.8      2.9
# Big spenders             26       2  372  135.9         1    1   1.0   1635.7
# Lost customers          390     140  373  265.2         1    1   1.0      3.8
#
#
#                           max    mean        sum
# Segment
# Best customers       279489.0  9388.4  4149656.1
# Loyal customers      123725.4  3588.6  1431839.1
# At risk               11581.8  1638.8   817773.5
# Potential loyalists   12393.7  1469.8   540869.8
# Needing attention      6748.8   646.9   483251.6
# About to sleep         1487.6   383.3   416613.7
# Can't lose them       21535.9  1661.2   252497.9
# Recent customers       1162.6   335.4    71102.3
# Big spenders           6207.7  2561.3    66593.8
# Lost customers          300.5   157.8    61550.7

# %% [markdown]
# ### Data visualisation

# %%
#flattening column index
rfm_analysis.columns = rfm_analysis.columns.map('_'.join)

# %%
#reseting index
rfm_analysis = rfm_analysis.reset_index()
rfm_analysis
# Out:
#                Segment  Segment_count  Recency_min  Recency_max  Recency_mean  \
# 0       Best customers            442            0           16           5.9
# 1      Loyal customers            399            0           49          24.9
# 2              At risk            499           50          138          80.8
# 3  Potential loyalists            368            0           16           7.4
# 4    Needing attention            747           17           72          30.1
# 5       About to sleep           1087           50          373         156.7
# 6      Can't lose them            152          140          366         206.8
# 7     Recent customers            212            0           16           8.1
# 8         Big spenders             26            2          372         135.9
# 9       Lost customers            390          140          373         265.2
#
#    Frequency_min  Frequency_max  Frequency_mean  Monetary_min  Monetary_max  \
# 0              7            248            20.1        1632.4      279489.0
# 1              4             76             9.9         191.2      123725.4
# 2              2             20             4.9         102.0       11581.8
# 3              2              6             4.3         151.2       12393.7
# 4              1              7             2.6           0.0        6748.8
# 5              1              9             1.7           0.0        1487.6
# 6              2             35             4.2         658.3       21535.9
# 7              1              3             1.8           2.9        1162.6
# 8              1              1             1.0        1635.7        6207.7
# 9              1              1             1.0           3.8         300.5
#
#    Monetary_mean  Monetary_sum
# 0         9388.4     4149656.1
# 1         3588.6     1431839.1
# 2         1638.8      817773.5
# 3         1469.8      540869.8
# 4          646.9      483251.6
# 5          383.3      416613.7
# 6         1661.2      252497.9
# 7          335.4       71102.3
# 8         2561.3       66593.8
# 9          157.8       61550.7

# %%
#display table for user
rfm_analysis_to_display = rfm_analysis.set_index('Segment')
print(f"RFM analysis for the period of: {start_date_object} to {end_date_object}:\n")
print(rfm_analysis_to_display)
# Out:
# RFM analysis for the period of: 2010-12-01 to 2011-12-09:
#
#                      Segment_count  Recency_min  Recency_max  Recency_mean  \
# Segment
# Best customers                 442            0           16           5.9
# Loyal customers                399            0           49          24.9
# At risk                        499           50          138          80.8
# Potential loyalists            368            0           16           7.4
# Needing attention              747           17           72          30.1
# About to sleep                1087           50          373         156.7
# Can't lose them                152          140          366         206.8
# Recent customers               212            0           16           8.1
# Big spenders                    26            2          372         135.9
# Lost customers                 390          140          373         265.2
#
#                      Frequency_min  Frequency_max  Frequency_mean  \
# Segment
# Best customers                   7            248            20.1
# Loyal customers                  4             76             9.9
# At risk                          2             20             4.9
# Potential loyalists              2              6             4.3
# Needing attention                1              7             2.6
# About to sleep                   1              9             1.7
# Can't lose them                  2             35             4.2
# Recent customers                 1              3             1.8
# Big spenders                     1              1             1.0
# Lost customers                   1              1             1.0
#
#                      Monetary_min  Monetary_max  Monetary_mean  Monetary_sum
# Segment
# Best customers             1632.4      279489.0         9388.4     4149656.1
# Loyal customers             191.2      123725.4         3588.6     1431839.1
# At risk                     102.0       11581.8         1638.8      817773.5
# Potential loyalists         151.2       12393.7         1469.8      540869.8
# Needing attention             0.0        6748.8          646.9      483251.6
# About to sleep                0.0        1487.6          383.3      416613.7
# Can't lose them             658.3       21535.9         1661.2      252497.9
# Recent customers              2.9        1162.6          335.4       71102.3
# Big spenders               1635.7        6207.7         2561.3       66593.8
# Lost customers                3.8         300.5          157.8       61550.7

# %%
# plotting avg Frequency and avg Recency in scatter plot with buble size representing Monetary sum
fig = px.scatter(rfm_analysis, x="Recency_mean", y="Frequency_mean", color="Segment",
                 hover_name="Segment", size=rfm_analysis['Monetary_sum'].tolist(), title='RFM by Segment',
                 labels={'Frequency_mean': 'AVG Frequency (number of orders)', 'Recency_mean': 'AVG Recency in days'},
                 hover_data=['Segment_count', 'Monetary_sum', 'Monetary_mean'], size_max=120, height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ae5acaea-52d3-40e3-bd87-89a1ab3499e1" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae5acaea-52d3-40e3-bd87-89a1ab3499e1")) {                    Plotly.newPlot(                        "ae5acaea-52d3-40e3-bd87-89a1ab3499e1",                        [{"customdata":[[442,4149656.1,9388.4]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSegment=Best customers\u003cbr\u003eAVG Recency in days=%{x}\u003cbr\u003eAVG Frequency (number of orders)=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003eSegment_count=%{customdata[0]}\u003cbr\u003eMonetary_sum=%{customdata[1]}\u003cbr\u003eMonetary_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Best customers"],"legendgroup":"Best customers","marker":{"color":"#636efa","size":[4149656.1],"sizemode":"area","sizeref":288.1705625,"symbol":"circle"},"mode":"markers","name":"Best customers","orientation":"v","showlegend":true,"x":[5.9],"xaxis":"x","y":[20.1],"yaxis":"y","type":"scatter"},{"customdata":[[399,1431839.1,3588.6]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSegment=Loyal customers\u003cbr\u003eAVG Recency in days=%{x}\u003cbr\u003eAVG Frequency (number of orders)=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003eSegment_count=%{customdata[0]}\u003cbr\u003eMonetary_sum=%{customdata[1]}\u003cbr\u003eMonetary_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Loyal customers"],"legendgroup":"Loyal customers","marker":{"color":"#EF553B","size":[1431839.1],"sizemode":"area","sizeref":288.1705625,"symbol":"circle"},"mode":"markers","name":"Loyal customers","orientation":"v","showlegend":true,"x":[24.9],"xaxis":"x","y":[9.9],"yaxis":"y","type":"scatter"},{"customdata":[[499,817773.5,1638.8]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSegment=At risk\u003cbr\u003eAVG Recency in days=%{x}\u003cbr\u003eAVG Frequency (number of orders)=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003eSegment_count=%{customdata[0]}\u003cbr\u003eMonetary_sum=%{customdata[1]}\u003cbr\u003eMonetary_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["At risk"],"legendgroup":"At risk","marker":{"color":"#00cc96","size":[817773.5],"sizemode":"area","sizeref":288.1705625,"symbol":"circle"},"mode":"markers","name":"At risk","orientation":"v","showlegend":true,"x":[80.8],"xaxis":"x","y":[4.9],"yaxis":"y","type":"scatter"},{"customdata":[[368,540869.8,1469.8]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSegment=Potential loyalists\u003cbr\u003eAVG Recency in days=%{x}\u003cbr\u003eAVG Frequency (number of orders)=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003eSegment_count=%{customdata[0]}\u003cbr\u003eMonetary_sum=%{customdata[1]}\u003cbr\u003eMonetary_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Potential loyalists"],"legendgroup":"Potential loyalists","marker":{"color":"#ab63fa","size":[540869.8],"sizemode":"area","sizeref":288.1705625,"symbol":"circle"},"mode":"markers","name":"Potential loyalists","orientation":"v","showlegend":true,"x":[7.4],"xaxis":"x","y":[4.3],"yaxis":"y","type":"scatter"},{"customdata":[[747,483251.6,646.9]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSegment=Needing attention\u003cbr\u003eAVG Recency in days=%{x}\u003cbr\u003eAVG Frequency (number of orders)=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003eSegment_count=%{customdata[0]}\u003cbr\u003eMonetary_sum=%{customdata[1]}\u003cbr\u003eMonetary_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002f ...

# %%
#creating bar plot representing monetary sum by Segment
fig = px.bar(rfm_analysis, y='Segment', x='Monetary_sum', title='Monetary by Segment', orientation='h',
             color='Segment', color_continuous_scale='Viridis', hover_data=['Monetary_min', 'Monetary_max', 'Monetary_mean'],
             labels={'Monetary_sum': 'Monetary (sales value in EUR)'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="75e35d9c-f6f3-4b78-9f0e-578e1ac43bab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75e35d9c-f6f3-4b78-9f0e-578e1ac43bab")) {                    Plotly.newPlot(                        "75e35d9c-f6f3-4b78-9f0e-578e1ac43bab",                        [{"alignmentgroup":"True","customdata":[[1632.4,279489.0,9388.4]],"hovertemplate":"Segment=%{y}\u003cbr\u003eMonetary (sales value in EUR)=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Best customers","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Best customers","offsetgroup":"Best customers","orientation":"h","showlegend":true,"textposition":"auto","x":[4149656.1],"xaxis":"x","y":["Best customers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[191.2,123725.4,3588.6]],"hovertemplate":"Segment=%{y}\u003cbr\u003eMonetary (sales value in EUR)=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loyal customers","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Loyal customers","offsetgroup":"Loyal customers","orientation":"h","showlegend":true,"textposition":"auto","x":[1431839.1],"xaxis":"x","y":["Loyal customers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[102.0,11581.8,1638.8]],"hovertemplate":"Segment=%{y}\u003cbr\u003eMonetary (sales value in EUR)=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"At risk","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"At risk","offsetgroup":"At risk","orientation":"h","showlegend":true,"textposition":"auto","x":[817773.5],"xaxis":"x","y":["At risk"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[151.2,12393.7,1469.8]],"hovertemplate":"Segment=%{y}\u003cbr\u003eMonetary (sales value in EUR)=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Potential loyalists","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Potential loyalists","offsetgroup":"Potential loyalists","orientation":"h","showlegend":true,"textposition":"auto","x":[540869.8],"xaxis":"x","y":["Potential loyalists"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0.0,6748.8,646.9]],"hovertemplate":"Segment=%{y}\u003cbr\u003eMonetary (sales value in EUR)=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Needing attention","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Needing attention","offsetgroup":"Needing attention","orientation":"h","showlegend":true,"textposition":"auto","x":[483251.6],"xaxis":"x","y":["Needing attention"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0.0,1487.6,383.3]],"hovertemplate":"Segment=%{y}\u003cbr\u003eMonetary (sales value in EUR)=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"About to sleep","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"About to sleep","offsetgroup":"About to sleep","orientation":"h","showlegend":true,"textposition":"auto","x" ...

# %%
#creating bar chart reoresenting number of custmers in each Segment
fig = px.bar(rfm_analysis, y='Segment', x='Segment_count', title='Number of customers by Segment', orientation='h',
             color='Segment', hover_data=['Monetary_sum', 'Recency_mean', 'Frequency_mean'],
             labels={'Segment_count': 'Number of customers'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ad2918a3-ea9f-4b6f-9840-5036a5e1c079" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad2918a3-ea9f-4b6f-9840-5036a5e1c079")) {                    Plotly.newPlot(                        "ad2918a3-ea9f-4b6f-9840-5036a5e1c079",                        [{"alignmentgroup":"True","customdata":[[4149656.1,5.9,20.1]],"hovertemplate":"Segment=%{y}\u003cbr\u003eNumber of customers=%{x}\u003cbr\u003eMonetary_sum=%{customdata[0]}\u003cbr\u003eRecency_mean=%{customdata[1]}\u003cbr\u003eFrequency_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Best customers","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Best customers","offsetgroup":"Best customers","orientation":"h","showlegend":true,"textposition":"auto","x":[442],"xaxis":"x","y":["Best customers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1431839.1,24.9,9.9]],"hovertemplate":"Segment=%{y}\u003cbr\u003eNumber of customers=%{x}\u003cbr\u003eMonetary_sum=%{customdata[0]}\u003cbr\u003eRecency_mean=%{customdata[1]}\u003cbr\u003eFrequency_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loyal customers","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Loyal customers","offsetgroup":"Loyal customers","orientation":"h","showlegend":true,"textposition":"auto","x":[399],"xaxis":"x","y":["Loyal customers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[817773.5,80.8,4.9]],"hovertemplate":"Segment=%{y}\u003cbr\u003eNumber of customers=%{x}\u003cbr\u003eMonetary_sum=%{customdata[0]}\u003cbr\u003eRecency_mean=%{customdata[1]}\u003cbr\u003eFrequency_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"At risk","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"At risk","offsetgroup":"At risk","orientation":"h","showlegend":true,"textposition":"auto","x":[499],"xaxis":"x","y":["At risk"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[540869.8,7.4,4.3]],"hovertemplate":"Segment=%{y}\u003cbr\u003eNumber of customers=%{x}\u003cbr\u003eMonetary_sum=%{customdata[0]}\u003cbr\u003eRecency_mean=%{customdata[1]}\u003cbr\u003eFrequency_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Potential loyalists","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Potential loyalists","offsetgroup":"Potential loyalists","orientation":"h","showlegend":true,"textposition":"auto","x":[368],"xaxis":"x","y":["Potential loyalists"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[483251.6,30.1,2.6]],"hovertemplate":"Segment=%{y}\u003cbr\u003eNumber of customers=%{x}\u003cbr\u003eMonetary_sum=%{customdata[0]}\u003cbr\u003eRecency_mean=%{customdata[1]}\u003cbr\u003eFrequency_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Needing attention","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Needing attention","offsetgroup":"Needing attention","orientation":"h","showlegend":true,"textposition":"auto","x":[747],"xaxis":"x","y":["Needing attention"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[416613.7,156.7,1.7]],"hovertemplate":"Segment=%{y}\u003cbr\u003eNumber of customers=%{x}\u003cbr\u003eMonetary_sum=%{customdata[0]}\u003cbr\u003eRecency_mean=%{customdata[1]}\u003cbr\u003eFrequency_mean=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"About to sleep","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"About to sleep","offsetgroup":"About to sleep","orientation":"h","showlegend":true,"textposition":"auto","x":[1087],"xaxis":"x","y":["About to sleep"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True ...

# %%
#creating bar chart for avg Recency by Segment
fig = px.bar(rfm_analysis, y='Segment', x='Recency_mean', title='AVG Recency by Segment', orientation='h',
             color='Segment', color_continuous_scale='Viridis', hover_data=['Recency_min', 'Recency_max', 'Recency_mean', 'Monetary_sum', 'Segment_count'],
             labels={'Recency_mean': 'Recency in days'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="25e0906d-4806-4225-b9e3-9927003e1992" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25e0906d-4806-4225-b9e3-9927003e1992")) {                    Plotly.newPlot(                        "25e0906d-4806-4225-b9e3-9927003e1992",                        [{"alignmentgroup":"True","customdata":[[0,16,4149656.1,442]],"hovertemplate":"Segment=%{y}\u003cbr\u003eRecency in days=%{x}\u003cbr\u003eRecency_min=%{customdata[0]}\u003cbr\u003eRecency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Best customers","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Best customers","offsetgroup":"Best customers","orientation":"h","showlegend":true,"textposition":"auto","x":[5.9],"xaxis":"x","y":["Best customers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0,49,1431839.1,399]],"hovertemplate":"Segment=%{y}\u003cbr\u003eRecency in days=%{x}\u003cbr\u003eRecency_min=%{customdata[0]}\u003cbr\u003eRecency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loyal customers","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Loyal customers","offsetgroup":"Loyal customers","orientation":"h","showlegend":true,"textposition":"auto","x":[24.9],"xaxis":"x","y":["Loyal customers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[50,138,817773.5,499]],"hovertemplate":"Segment=%{y}\u003cbr\u003eRecency in days=%{x}\u003cbr\u003eRecency_min=%{customdata[0]}\u003cbr\u003eRecency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"At risk","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"At risk","offsetgroup":"At risk","orientation":"h","showlegend":true,"textposition":"auto","x":[80.8],"xaxis":"x","y":["At risk"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0,16,540869.8,368]],"hovertemplate":"Segment=%{y}\u003cbr\u003eRecency in days=%{x}\u003cbr\u003eRecency_min=%{customdata[0]}\u003cbr\u003eRecency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Potential loyalists","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Potential loyalists","offsetgroup":"Potential loyalists","orientation":"h","showlegend":true,"textposition":"auto","x":[7.4],"xaxis":"x","y":["Potential loyalists"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[17,72,483251.6,747]],"hovertemplate":"Segment=%{y}\u003cbr\u003eRecency in days=%{x}\u003cbr\u003eRecency_min=%{customdata[0]}\u003cbr\u003eRecency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Needing attention","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Needing attention","offsetgroup":"Needing attention","orientation":"h","showlegend":true,"textposition":"auto","x":[30.1],"xaxis":"x","y":["Needing attention"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[50,373,416613.7,1087]],"hovertemplate":"Segment=%{y}\u003cbr\u003eRecency in days=%{x}\u003cbr\u003eRecency_min=%{customdata[0]}\u003cbr\u003eRecency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"About to sleep","marker":{"color":"#19d3f3","patter ...

# %%
#creating bar chart for avg Frequency by Segment
fig = px.bar(rfm_analysis, y='Segment', x='Frequency_mean', title='AVG Frequency by Segment', orientation='h',
             color='Segment', color_continuous_scale='Viridis', hover_data=['Frequency_min', 'Frequency_max', 'Frequency_mean', 'Monetary_sum', 'Segment_count'],
             labels={'Frequency_mean': 'AVG number of orders'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1360b38c-786c-42e1-9b0e-0185c1a224e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1360b38c-786c-42e1-9b0e-0185c1a224e0")) {                    Plotly.newPlot(                        "1360b38c-786c-42e1-9b0e-0185c1a224e0",                        [{"alignmentgroup":"True","customdata":[[7,248,4149656.1,442]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG number of orders=%{x}\u003cbr\u003eFrequency_min=%{customdata[0]}\u003cbr\u003eFrequency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Best customers","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Best customers","offsetgroup":"Best customers","orientation":"h","showlegend":true,"textposition":"auto","x":[20.1],"xaxis":"x","y":["Best customers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4,76,1431839.1,399]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG number of orders=%{x}\u003cbr\u003eFrequency_min=%{customdata[0]}\u003cbr\u003eFrequency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loyal customers","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Loyal customers","offsetgroup":"Loyal customers","orientation":"h","showlegend":true,"textposition":"auto","x":[9.9],"xaxis":"x","y":["Loyal customers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2,20,817773.5,499]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG number of orders=%{x}\u003cbr\u003eFrequency_min=%{customdata[0]}\u003cbr\u003eFrequency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"At risk","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"At risk","offsetgroup":"At risk","orientation":"h","showlegend":true,"textposition":"auto","x":[4.9],"xaxis":"x","y":["At risk"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2,6,540869.8,368]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG number of orders=%{x}\u003cbr\u003eFrequency_min=%{customdata[0]}\u003cbr\u003eFrequency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Potential loyalists","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Potential loyalists","offsetgroup":"Potential loyalists","orientation":"h","showlegend":true,"textposition":"auto","x":[4.3],"xaxis":"x","y":["Potential loyalists"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1,7,483251.6,747]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG number of orders=%{x}\u003cbr\u003eFrequency_min=%{customdata[0]}\u003cbr\u003eFrequency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Needing attention","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Needing attention","offsetgroup":"Needing attention","orientation":"h","showlegend":true,"textposition":"auto","x":[2.6],"xaxis":"x","y":["Needing attention"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1,9,416613.7,1087]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG number of orders=%{x}\u003cbr\u003eFrequency_min=%{customdata[0]}\u003cbr\u003eFrequency_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"About  ...

# %%
#creating bar chart for avg Monetary by Segment
fig = px.bar(rfm_analysis, y='Segment', x='Monetary_mean', title='AVG Monetary by Segment', orientation='h',
             color='Segment', color_continuous_scale='Viridis', hover_data=['Monetary_min', 'Monetary_max', 'Monetary_mean', 'Monetary_sum', 'Segment_count'],
             labels={'Monetary_mean': 'AVG sales value in EUR'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="694b7b10-5ff1-4fdf-a2de-b650bef9fe1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("694b7b10-5ff1-4fdf-a2de-b650bef9fe1d")) {                    Plotly.newPlot(                        "694b7b10-5ff1-4fdf-a2de-b650bef9fe1d",                        [{"alignmentgroup":"True","customdata":[[1632.4,279489.0,4149656.1,442]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG sales value in EUR=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Best customers","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Best customers","offsetgroup":"Best customers","orientation":"h","showlegend":true,"textposition":"auto","x":[9388.4],"xaxis":"x","y":["Best customers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[191.2,123725.4,1431839.1,399]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG sales value in EUR=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loyal customers","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Loyal customers","offsetgroup":"Loyal customers","orientation":"h","showlegend":true,"textposition":"auto","x":[3588.6],"xaxis":"x","y":["Loyal customers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[102.0,11581.8,817773.5,499]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG sales value in EUR=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"At risk","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"At risk","offsetgroup":"At risk","orientation":"h","showlegend":true,"textposition":"auto","x":[1638.8],"xaxis":"x","y":["At risk"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[151.2,12393.7,540869.8,368]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG sales value in EUR=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Potential loyalists","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Potential loyalists","offsetgroup":"Potential loyalists","orientation":"h","showlegend":true,"textposition":"auto","x":[1469.8],"xaxis":"x","y":["Potential loyalists"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0.0,6748.8,483251.6,747]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG sales value in EUR=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Needing attention","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Needing attention","offsetgroup":"Needing attention","orientation":"h","showlegend":true,"textposition":"auto","x":[646.9],"xaxis":"x","y":["Needing attention"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0.0,1487.6,416613.7,1087]],"hovertemplate":"Segment=%{y}\u003cbr\u003eAVG sales value in EUR=%{x}\u003cbr\u003eMonetary_min=%{customdata[0]}\u003cbr\u003eMonetary_max=%{customdata[1]}\u003cbr\u003eMonetary_sum=%{customdata[2]}\u003cbr\u003eSegment_count=%{customdata[ ...
